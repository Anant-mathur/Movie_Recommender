# %% [markdown]
# # Movies Recommender System
#
#
# In this notebook, I will attempt at implementing a few recommendation algorithms (content based, popularity based and collaborative filtering) and try to build an ensemble of these models to come up with our final recommendation system. With us, we have two MovieLens datasets.
#
# * **The Movies Dataset:** A dataset of 4814 rows containing columns such as budget, genres etc.
# * **The Credits Dataset:** A dataset of 4814 rows containing columns such as movie_id, title, cast, crew

# %%
# Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credits_df = pd.read_csv('credits.csv',low_memory=False)
movies_df = pd.read_csv('movies.csv',low_memory=False)

# %%
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_df.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
credits_df.shape, movies_df.shape
# Out:
# ((4803, 4), (4803, 20))

# %%
movies_df.drop('homepage',axis=1)
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies_df = movies_df.merge(credits_df,on='title')

# %%
# Creating a correlation matrix
fig,ax = plt.subplots(figsize=(10,10))
corr = movies_df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,ax=ax);

# %%
movies_df = movies_df[['movie_id','title','overview','genres','keywords','cast','crew','vote_average','runtime','revenue']]

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4808 entries, 0 to 4807
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      4808 non-null   int64
#  1   title         4808 non-null   object
#  2   overview      4805 non-null   object
#  3   genres        4808 non-null   object
#  4   keywords      4808 non-null   object
#  5   cast          4808 non-null   object
#  6   crew          4808 non-null   object
#  7   vote_average  4808 non-null   float64
#  8   runtime       4806 non-null   float64
#  9   revenue       4808 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 413.2+ KB

# %%
# Check if there are any missing values present in the dataset
movies_df.isna().sum()
# Out:
# movie_id        0
# title           0
# overview        3
# genres          0
# keywords        0
# cast            0
# crew            0
# vote_average    0
# runtime         2
# revenue         0
# dtype: int64

# %%
movies_df.dropna(inplace=True)

# %%
movies_df.isna().sum()
# Out:
# movie_id        0
# title           0
# overview        0
# genres          0
# keywords        0
# cast            0
# crew            0
# vote_average    0
# runtime         0
# revenue         0
# dtype: int64

# %%
movies_df.duplicated().sum()
# This indicates that we have no duplicate values
# Out:
# 0

# %%
movies_df.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
# Convert the dictionary into a list so it is easier to evaluate ( for genres and keywords)
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies_df['genres'] = movies_df['genres'].apply(convert)
movies_df['keywords'] = movies_df['keywords'].apply(convert)
movies_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# ...

# %%
def convert3(obj):
    L = []
    counter=0
    for i in ast.literal_eval(obj):
        if counter!=3:
            L.append(i['name'])
            counter+=1
        else:
            break
            
        return L

# %%
movies_df['cast'] = movies_df['cast'].apply(convert)

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
def get_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies_df['crew'] = movies_df['crew'].apply(get_director)

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# Let's check the overview for the first movie
movies_df['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
# We have split the overview and created a list containing all the words
movies_df['overview'] = movies_df['overview'].apply(lambda x:x.split())

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# Let's replace the spaces between words (if any)
movies_df['genres'] = movies_df['genres'].apply(lambda x:[i.replace(' ','') for i in x])
movies_df['keywords'] = movies_df['keywords'].apply(lambda x:[i.replace(' ','') for i in x])
movies_df['cast'] = movies_df['cast'].apply(lambda x:[i.replace(' ','') for i in x])
movies_df['crew'] = movies_df['crew'].apply(lambda x:[i.replace(' ','') for i in x])

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
# Let's create a new column and add overview, genres, keywords, cast and crew to it (merge them)
movies_df['tags'] = movies_df['overview']+movies_df['genres']+movies_df['keywords']+movies_df['cast']+movies_df['crew']

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies_df['tags'][0]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d',
#  'SamWorthington',
#  'ZoeSaldana',
#  'SigourneyWeaver',
#  'StephenLang',
#  'MichelleRodriguez',
#  'GiovanniRibisi',
#  'JoelDavidMoore',
#  'CCHPounder',
#  'WesStudi',
#  'LazAlonso',
#  'DileepRao',
#  'MattGerald',
#  'SeanAnthonyMoran',
#  'JasonWhyte',
# ...

# %%
# Let's create a dataframe containing movie_id, title and all the other information( which was stored in tags)
movies = movies_df[['movie_id','title','tags','revenue','vote_average','runtime']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags     revenue  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  2787965087
# 1  [Captain, Barbossa,, long, believed, to, be, d...   961000000
# 2  [A, cryptic, message, from, Bond’s, past, send...   880674609
# 3  [Following, the, death, of, District, Attorney...  1084939099
# 4  [John, Carter, is, a, war-weary,, former, mili...   284139100
#
#    vote_average  runtime
# 0           7.2    162.0
# 1           6.9    169.0
# 2           6.3    148.0
# 3           7.6    165.0
# 4           6.1    132.0

# %%
movies['tags'] = movies['tags'].apply(lambda x: ' '.join(x))
# Out:
# C:\Users\Anant Roop Mathur\AppData\Local\Temp\ipykernel_42328\2303228016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['tags'].apply(lambda x: ' '.join(x))

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags     revenue  \
# 0  In the 22nd century, a paraplegic Marine is di...  2787965087
# 1  Captain Barbossa, long believed to be dead, ha...   961000000
# 2  A cryptic message from Bond’s past sends him o...   880674609
# 3  Following the death of District Attorney Harve...  1084939099
# 4  John Carter is a war-weary, former military ca...   284139100
#
#    vote_average  runtime
# 0           7.2    162.0
# 1           6.9    169.0
# 2           6.3    148.0
# 3           7.6    165.0
# 4           6.1    132.0

# %% [markdown]
# * Now, we see that the tags column has a lot of information like overview, genres, keywords, cast and crew. So, we can infer from this data and later cluster the data by matching similar keywords, cast, crew or anything and later recommend a movie in the same cluster closest to the data point provided to us

# %%
# What we are trying to do is convert everything into lowercase for tags
movies['tags'] = movies['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\Anant Roop Mathur\AppData\Local\Temp\ipykernel_42328\1779477943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['tags'].apply(lambda x:x.lower())

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags     revenue  \
# 0  in the 22nd century, a paraplegic marine is di...  2787965087
# 1  captain barbossa, long believed to be dead, ha...   961000000
# 2  a cryptic message from bond’s past sends him o...   880674609
# 3  following the death of district attorney harve...  1084939099
# 4  john carter is a war-weary, former military ca...   284139100
#
#    vote_average  runtime
# 0           7.2    162.0
# 1           6.9    169.0
# 2           6.3    148.0
# 3           7.6    165.0
# 4           6.1    132.0

# %%
# let's use Count Vectorizer for Feature Extraction
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectorized = vectorizer.fit_transform(movies['tags']).toarray()

# %%
vectorized.shape
# Out:
# (4805, 5000)

# %%
vectorized[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
len(vectorizer.get_feature_names_out())
# Out:
# 5000

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    L = []
    for i in text.split():
        L.append(ps.stem(i))
    return " ".join(L)

# %%
movies['tags'] = movies['tags'].apply(stem)
# Out:
# C:\Users\Anant Roop Mathur\AppData\Local\Temp\ipykernel_42328\3456099318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['tags'].apply(stem)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags     revenue  \
# 0  in the 22nd century, a parapleg marin is dispa...  2787965087
# 1  captain barbossa, long believ to be dead, ha c...   961000000
# 2  a cryptic messag from bond’ past send him on a...   880674609
# 3  follow the death of district attorney harvey d...  1084939099
# 4  john carter is a war-weary, former militari ca...   284139100
#
#    vote_average  runtime
# 0           7.2    162.0
# 1           6.9    169.0
# 2           6.3    148.0
# 3           7.6    165.0
# 4           6.1    132.0

# %%
movies['tags'][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington zoesaldana sigourneyweav stephenlang michellerodriguez giovanniribisi joeldavidmoor cchpounder wesstudi lazalonso dileeprao mattgerald seananthonymoran jasonwhyt scottlawr kellykilgour jamespatrickpitt seanpatrickmurphi peterdillon kevindorman kelsonhenderson davidvanhorn jacobtomuri michaelblain-rozgay joncurri lukehawk woodyschultz petermensah soniaye jahnelcurfman ilramchoi kylawarren lisaroumain debrawilson chrismala taylorkibbi jodielandau julielamm cullenb.madden josephbradymadden frankietorr austinwilson sarawilson tamicawashington-mil lucybri nathanmeist gerryblair matthewchamberlain paulyat wrayw
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectorized)

# %%
similarity.shape
# Out:
# (4805, 4805)

# %%
similarity[0]
# Out:
# array([1.        , 0.07142857, 0.05143445, ..., 0.02353104, 0.02571722,
#        0.        ])

# %%
def recommend(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(range(len(distances)), key=lambda x: distances[x], reverse=True)[1:6]

    print(f"Movies similar to '{movie}':")
    for i in movies_list:
        
        title = movies.iloc[i].title
        revenue = movies.iloc[i].revenue
        runtime = movies.iloc[i].runtime
        vote_average = movies.iloc[i].vote_average
        print(f'''Title: {title} 
              Revenue: {revenue} dollars
              Runtime: {runtime} minutes
              Vote Average: {vote_average}''')

# Example usage:
recommend("The Avengers")
# Out:
# Movies similar to 'The Avengers':
# Title: Avengers: Age of Ultron
#               Revenue: 1405403694 dollars
#               Runtime: 141.0 minutes
#               Vote Average: 7.3
# Title: Iron Man 3
#               Revenue: 1215439994 dollars
#               Runtime: 130.0 minutes
#               Vote Average: 6.8
# Title: Iron Man
#               Revenue: 585174222 dollars
#               Runtime: 126.0 minutes
#               Vote Average: 7.4
# Title: Iron Man 2
#               Revenue: 623933331 dollars
#               Runtime: 124.0 minutes
#               Vote Average: 6.6
# Title: Captain America: Civil War
#               Revenue: 1153304495 dollars
#               Runtime: 147.0 minutes
#               Vote Average: 7.1
